# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import numpy as np

# %%
dataset = pd.read_csv('/content/new_model.csv')

# %%
X = dataset.drop('Class', axis=1)  # Features
y = dataset['Class']  # Target variable

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# Create an AdaBoost classifier
ada_classifier = AdaBoostClassifier(n_estimators=50, random_state=42)  #can adjust the number of estimators as needed

# %%
# Fit the model to the training data
ada_classifier.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
# Make predictions on the test data
y_pred = ada_classifier.predict(X_test)

# %%
# Compute the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Visualize the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (AdaBoost)')
plt.show()

# %%
# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[28  0]
#  [ 0 52]]

# %%
# Calculate and print the classification report
print("\nClassification Report:")
class_report = classification_report(y_test, y_pred)
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        28
#            1       1.00      1.00      1.00        52
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80
